# %%
import bittensor as bt
# Out:
# 2025-06-18 13:45:14 INFO     Enabling default logging (Warning level)
# 2025-06-18 13:45:14.308 |       INFO       | Enabling default logging (Warning level)

# %%
import affine as af

# %%
import affine as af
# await af.run(
#     models=['unsloth/gemma-3-4b-it'],
#     n = 30,
#     c = 20,
#     env = af.environments.SAT1( n= 3, k = 2, m = 3 )
# )
results = af.results( models=['unsloth/gemma-3-4b-it'], env = af.environments.SAT1 )
len(results[0])
# Out:
# 143

# %%
results[0]
# Out:
# [{'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x2) ∧ (x1 ∨ ¬x3) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ ¬x1) ∧ (¬x3 ∨ ¬x2) ∧ (x1 ∨ ¬x2) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x2) ∧ (¬x3 ∨ ¬x1) ∧ (¬x2 ∨ ¬x1) ∧ (¬x3 ∨ x1) ∧ (¬x1 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.2855397910025204,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 2,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ x1) ∧ (x1 ∨ ¬x2) ∧ (¬x2 ∨ x1) ∧ (x1 ∨ ¬x2) ∧ (x3 ∨ x2) ∧ (x3 ∨ ¬x2) ∧ (¬x3 ∨ x1) ∧ (x3 ∨ ¬x1) ∧ (¬x3 ∨ ¬x2) ∧ (¬x2 ∨ ¬x3) ∧ (x3 ∨ ¬x2) ∧ (x1 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.6223799170111306,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 3,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ ¬x3) ∧ (x3 ∨ ¬x1) ∧ (x2 ∨ x3) ∧ (x2 ∨ ¬x1) ∧ (¬x3 ∨ ¬x1) ∧ (¬x3 ∨ ¬x2) ∧ (x2 ∨ ¬x3) ∧ (¬x1 ∨ ¬x3) ∧ (¬x3 ∨ ¬x1) ∧ (¬x3 ∨ x2) ∧ (¬x1 ∨ x3) ∧ (¬x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': "Let's analyze the 2-SAT formula:\n(x1 ∨ ¬x3) ∧ (x3 ∨ ¬x1) ∧ (x2 ∨ x3) ∧ (x2 ∨ ¬x1) ∧ (¬x3 ∨ ¬x1) ∧ (¬x3 ∨ ¬x2) ∧ (x2 ∨ ¬x3) ∧ (¬x1 ∨ ¬x3) ∧ (¬x3 ∨ ¬x1) ∧ (¬x3 ∨ x2) ∧ (¬x1 ∨ x3) ∧ (¬x3 ∨ ¬x2)\n\nWe can use the Davis-Putnam-Logemann-Loveland (DPLL) algorithm or a simpler approach like repeatedly testing assignments.\n\nLet's try x1 = True.\n- (True ∨ ¬x3) is always true.\n- (x3 ∨ True) is always true.\n- (x2 ∨ x3) becomes (x2 ∨ x3)\n- (x2 ∨ False) becomes (x2)\n- (¬x3 ∨ ¬True) becomes (¬x3 ∨ False) which simplifies to ¬x3\n- (¬x3 ∨ ¬x2) becomes (¬x3 ∨ ¬x2)\n- (x2 ∨ ¬x3) becomes (x2 ∨ ¬x3)\n- (¬True ∨ ¬x3) becomes (False ∨ ¬x3) which simplifies to ¬x3\n- (¬x3 ∨ ¬True) becomes (¬x3 ∨ False) which simplifies to ¬x3\n- (¬x3 ∨ x2) becomes (¬x3 ∨ x2)\n- (¬True ∨ x3) becomes (False ∨ x3) which simplifies to x3\n- (¬x3 ∨ ¬x2) becomes (¬x3 ∨ ¬x2)\n\nSo, if x1 = True, we need x3 = True and x2 = False.\nLet's check if this assignment satisfies all clauses:\n- (True ∨ ¬True) = True\n- (True ∨ True) = True\n- (False ∨ True) = True\n- (False ∨ False) = False - This is a problem!\n\nLet's try x1 = False.\n- (False ∨ ¬x3) = ¬x3\n- (x3 ∨ False) = x3\n- (x2 ∨ x3) becomes (x2 ∨ x3)\n- (x2 ∨ True) = True\n- (¬x3 ∨ True) = True\n- (¬x3 ∨ ¬x2) becomes (¬x3 ∨ ¬x2)\n- (x2 ∨ ¬x3) becomes (x2 ∨ ¬x3)\n- (¬False ∨ ¬x3) = True ∨ ¬x3 = True\n- (¬x3 ∨ ¬False) = ¬x3 ∨ True = True\n- (¬x3 ∨ x2) becomes (¬x3 ∨ x2)\n- (¬False ∨ x3) = True ∨ x3 = True\n- (¬x3 ∨ ¬x2) becomes (¬x3 ∨ ¬x2)\n\nIf x1 = False, we have:\n- ¬x3\n- x3\n- (x2 ∨ x3)\n- (x2 ∨ True) = True\n- (¬x3 ∨ ¬x2)\n- (x2 ∨ ¬x3)\n- (True ∨ ¬x3) = True\n- (¬x3 ∨ True) = True\n- (¬x3 ∨ x2)\n- (True ∨ x3) = True\n- (¬x3 ∨ ¬x2)\n\nLet's try x1 = False, x2 = False, x3 = False:\n- (False ∨ True) = True\n- (False ∨ False) = False - This is a problem.\n\nLet's try x1 = False, x2 = True, x3 = False:\n- (False ∨ True) = True\n- (False ∨ False) = False - This is a problem.\n\nLet's try x1 = False, x2 = False, x3 = True:\n- (False ∨ False) = False - This is a problem.\n\nLet's try x1 = True, x2 = False, x3 = False:\n- (True ∨ True) = True\n- (False ∨ True) = True\n- (False ∨ False) = False - This is a problem.\n\nLet's try x1 = True, x2 = True, x3 = False:\n- (True ∨ True) = True\n- (False ∨ True) = True\n- (True ∨ False) = True\n- (True ∨ False) = True\n- (True ∨ False) = True\n- (True ∨ False) = True\n- (True ∨ True) = True\n- (False ∨ True) = True\n- (True ∨ False) = True\n- (False ∨ True) = True\n- (False ∨ False) = False - This is a problem.\n\nLet's try x1 = False, x2 = True, x3 = True:\n- (False ∨ False) = False - This is a problem.\n\nLet's try x1 = True, x2 = False, x3 = True:\n- (True ∨ False) = True\n- (True ∨ True) = True\n- (False ∨ True) = True\n- (False ∨ False) = False - This is a problem.\n\nConsider x1=False, x2=True, x3=False.\n(False ∨ True) ∧ (False ∨ False) ∧ (True ∨ False) ∧ (True ∨ True) ∧ (True ∨ True) ∧ (True ∨ False) ∧ (True ∨ True) ∧ (True ∨ False) ∧ (False ∨ True) ∧ (False ∨ True) ∧ (True ∨ False) ∧ (True ∨ True)\n= True ∧ False ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True\n= False\n\nConsider x1=True, x2=False, x3=False.\n(True ∨ True) ∧ (False ∨ True) ∧ (False ∨ False) ∧ (False ∨ False) ∧ (True ∨ False) ∧ (True ∨ True) ∧ (False ∨ True) ∧ (False ∨ True) ∧ (True ∨ False) ∧ (False ∨ True) ∧ (True ∨ False) ∧ (True ∨ True)\n= True ∧ True ∧ False ∧ False ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True\n= True\n\nLet's try x1=True, x2=False, x3=True.\n(True ∨ False) ∧ (True ∨ True) ∧ (False ∨ True) ∧ (False ∨ False) ∧ (False ∨ False) ∧ (False ∨ False) ∧ (False ∨ False) ∧ (True ∨ False) ∧ (False ∨ True) ∧ (False ∨ True) ∧ (False ∨ True) ∧ (False ∨ False)\n= True ∧ True ∧ True ∧ False ∧ False ∧ False ∧ False ∧ True ∧ True ∧ True ∧ True ∧ False\n= False\n\nLet's try x1=False, x2=True, x3=True.\n(False ∨ False) ∧ (True ∨ False) ∧ (True ∨ True) ∧ (True ∨ True) ∧ (False ∨ True) ∧ (False ∨ True) ∧ (True ∨ False) ∧ (True ∨ False) ∧ (False ∨ True) ∧ (Fal ...
#   'latency_seconds': 22.281513042005827,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': False, '3': True, '2': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 4,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ ¬x1) ∧ (x3 ∨ ¬x2) ∧ (¬x2 ∨ x3) ∧ (x1 ∨ x3) ∧ (x2 ∨ x3) ∧ (x2 ∨ x3) ∧ (x3 ∨ x1) ∧ (x2 ∨ x3) ∧ (¬x1 ∨ ¬x2) ∧ (x3 ∨ ¬x1) ∧ (x1 ∨ x2) ∧ (x1 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': "Let's analyze the 2-SAT formula:\n(¬x2 ∨ ¬x1) ∧ (x3 ∨ ¬x2) ∧ (¬x2 ∨ x3) ∧ (x1 ∨ x3) ∧ (x2 ∨ x3) ∧ (x2 ∨ x3) ∧ (x3 ∨ x1) ∧ (x2 ∨ x3) ∧ (¬x1 ∨ ¬x2) ∧ (x3 ∨ ¬x1) ∧ (x1 ∨ x2) ∧ (x1 ∨ ¬x2)\n\nWe can use a simple approach like repeatedly flipping the value of a variable that causes a conflict.\n\nLet's start with an initial assignment and see if we can find a solution.  Let's try x1=True, x2=False, x3=False.\n\n1. (¬False ∨ ¬True) = (True ∨ False) = True\n2. (False ∨ ¬False) = (False ∨ True) = True\n3. (¬False ∨ False) = (True ∨ False) = True\n4. (True ∨ False) = True\n5. (False ∨ False) = False\n6. (False ∨ False) = False\n7. (False ∨ True) = True\n8. (False ∨ False) = False\n9. (¬True ∨ ¬False) = (False ∨ True) = True\n10. (False ∨ ¬True) = (False ∨ False) = False\n11. (True ∨ False) = True\n12. (True ∨ ¬False) = (True ∨ True) = True\n\nSince clause 5 and 6 are false, this assignment is not a solution.\n\nLet's try x1=True, x2=True, x3=False.\n\n1. (¬True ∨ ¬True) = (False ∨ False) = False\n2. (False ∨ ¬True) = (False ∨ False) = False\n3. (¬True ∨ False) = (False ∨ False) = False\n4. (True ∨ False) = True\n5. (True ∨ False) = True\n6. (True ∨ False) = True\n7. (False ∨ True) = True\n8. (True ∨ False) = True\n9. (¬True ∨ ¬True) = (False ∨ False) = False\n10. (False ∨ ¬True) = (False ∨ False) = False\n11. (True ∨ True) = True\n12. (True ∨ ¬True) = (True ∨ False) = True\n\nSince clause 1, 2, 9, and 10 are false, this assignment is not a solution.\n\nLet's try x1=True, x2=False, x3=True.\n\n1. (¬False ∨ ¬True) = (True ∨ False) = True\n2. (True ∨ ¬False) = (True ∨ True) = True\n3. (¬False ∨ True) = (True ∨ True) = True\n4. (True ∨ True) = True\n5. (False ∨ True) = True\n6. (False ∨ True) = True\n7. (True ∨ True) = True\n8. (False ∨ True) = True\n9. (¬True ∨ ¬False) = (False ∨ True) = True\n10. (True ∨ ¬True) = (True ∨ False) = True\n11. (True ∨ False) = True\n12. (True ∨ ¬False) = (True ∨ True) = True\n\nAll clauses are satisfied. So, x1=True, x2=False, x3=True is a solution.\n\nFinal Answer: The final answer is $\\boxed{x1=True, x2=False, x3=True}$",
#   'latency_seconds': 11.007916665999801,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 5,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ x3) ∧ (x1 ∨ x2) ∧ (x3 ∨ x2) ∧ (¬x2 ∨ x1) ∧ (x1 ∨ x2) ∧ (¬x1 ∨ x3) ∧ (x1 ∨ x2) ∧ (x1 ∨ x3) ∧ (¬x2 ∨ x3) ∧ (x3 ∨ x1) ∧ (¬x1 ∨ x2) ∧ (¬x1 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.7389622920018155,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': True, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 6,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ ¬x2) ∧ (x2 ∨ x3) ∧ (¬x2 ∨ x1) ∧ (¬x2 ∨ ¬x1) ∧ (x3 ∨ ¬x2) ∧ (x3 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (¬x2 ∨ ¬x1) ∧ (¬x1 ∨ ¬x3) ∧ (x3 ∨ ¬x2) ∧ (x3 ∨ x1) ∧ (¬x1 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.9259080000047106,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 7,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ ¬x3) ∧ (¬x2 ∨ ¬x3) ∧ (¬x3 ∨ ¬x1) ∧ (x3 ∨ ¬x1) ∧ (x3 ∨ ¬x1) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ ¬x3) ∧ (¬x2 ∨ x3) ∧ (¬x3 ∨ ¬x1) ∧ (¬x1 ∨ ¬x3) ∧ (¬x3 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': "Let's analyze the 2-SAT formula:\n(x1 ∨ ¬x3) ∧ (¬x2 ∨ ¬x3) ∧ (¬x3 ∨ ¬x1) ∧ (x3 ∨ ¬x1) ∧ (x3 ∨ ¬x1) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ ¬x3) ∧ (¬x2 ∨ x3) ∧ (¬x3 ∨ ¬x1) ∧ (¬x1 ∨ ¬x3) ∧ (¬x3 ∨ ¬x1)\n\nNotice that (x3 ∨ ¬x1) and (¬x3 ∨ ¬x1) are identical.  We can simplify the formula by removing redundant clauses.  Also, (x1 ∨ ¬x3) appears multiple times.\n\nSimplified formula:\n(x1 ∨ ¬x3) ∧ (¬x2 ∨ ¬x3) ∧ (¬x3 ∨ ¬x1) ∧ (x3 ∨ ¬x1) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ ¬x3) ∧ (¬x2 ∨ x3) ∧ (¬x3 ∨ ¬x1)\n\nLet's try to find a satisfying assignment.\nWe can represent the clauses as:\n1. x1 ∨ ¬x3\n2. ¬x2 ∨ ¬x3\n3. ¬x3 ∨ ¬x1\n4. x3 ∨ ¬x1\n5. ¬x3 ∨ x2\n6. x1 ∨ ¬x3\n7. ¬x2 ∨ x3\n\nLet's try x1=True, x2=False, x3=False.\n1. True ∨ True: True\n2. ¬False ∨ ¬False: True ∨ True: True\n3. ¬False ∨ ¬True: True ∨ False: True\n4. False ∨ ¬True: False ∨ False: False\nThis assignment doesn't work because clause 4 is false.\n\nLet's try x1=True, x2=False, x3=True.\n1. True ∨ ¬True: True ∨ False: True\n2. ¬False ∨ ¬True: True ∨ False: True\n3. ¬True ∨ ¬True: False ∨ False: False\nThis assignment doesn't work because clause 3 is false.\n\nLet's try x1=False, x2=True, x3=False.\n1. False ∨ ¬False: False ∨ True: True\n2. ¬True ∨ ¬False: False ∨ True: True\n3. ¬False ∨ ¬False: True ∨ True: True\n4. False ∨ ¬False: False ∨ True: True\n5. ¬False ∨ False: True ∨ False: True\n6. False ∨ ¬False: False ∨ True: True\n7. ¬True ∨ False: False ∨ False: False\nThis assignment doesn't work because clause 7 is false.\n\nLet's try x1=False, x2=False, x3=True.\n1. False ∨ ¬True: False ∨ False: False\nThis assignment doesn't work because clause 1 is false.\n\nLet's try x1=True, x2=True, x3=False.\n1. True ∨ ¬False: True ∨ True: True\n2. ¬True ∨ ¬False: False ∨ True: True\n3. ¬False ∨ ¬True: True ∨ False: True\n4. False ∨ ¬True: False ∨ False: False\nThis assignment doesn't work because clause 4 is false.\n\nLet's try x1=True, x2=True, x3=True.\n1. True ∨ ¬True: True ∨ False: True\n2. ¬True ∨ ¬True: False ∨ False: False\nThis assignment doesn't work because clause 2 is false.\n\nLet's try x1=False, x2=False, x3=False.\n1. False ∨ ¬False: False ∨ True: True\n2. ¬False ∨ ¬False: True ∨ True: True\n3. ¬False ∨ ¬False: True ∨ True: True\n4. False ∨ ¬False: False ∨ True: True\n5. ¬False ∨ False: True ∨ False: True\n6. False ∨ ¬False: False ∨ True: True\n7. ¬False ∨ False: True ∨ False: True\n\nThis assignment works!\n\nFinal Answer: The final answer is $\\boxed{x1=True, x2=False, x3=False}$",
#   'latency_seconds': 12.701347125010216,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': True, '2': False, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 8,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ x3) ∧ (x1 ∨ x3) ∧ (x3 ∨ ¬x1) ∧ (x1 ∨ x3) ∧ (x2 ∨ x3) ∧ (x2 ∨ x3) ∧ (¬x1 ∨ x3) ∧ (x3 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (¬x3 ∨ x2) ∧ (¬x1 ∨ x3) ∧ (¬x2 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.5413027910108212,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 9,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ x2) ∧ (x2 ∨ ¬x3) ∧ (x2 ∨ x1) ∧ (x1 ∨ ¬x3) ∧ (x1 ∨ x3) ∧ (¬x1 ∨ x2) ∧ (¬x1 ∨ x3) ∧ (x2 ∨ ¬x3) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x1) ∧ (¬x2 ∨ x1) ∧ (x3 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 2.161060082988115,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': True, '3': True},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 10,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ ¬x3) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x1) ∧ (x2 ∨ x3) ∧ (x1 ∨ ¬x2) ∧ (x1 ∨ x3) ∧ (x3 ∨ x1) ∧ (¬x2 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (x3 ∨ ¬x1) ∧ (¬x2 ∨ x1) ∧ (¬x1 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': "Let's analyze the 2-SAT formula:\n(x1 ∨ ¬x3) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x1) ∧ (x2 ∨ x3) ∧ (x1 ∨ ¬x2) ∧ (x1 ∨ x3) ∧ (x3 ∨ x1) ∧ (¬x2 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (x3 ∨ ¬x1) ∧ (¬x2 ∨ x1) ∧ (¬x1 ∨ x3)\n\nNotice that (x1 ∨ ¬x3) and (¬x3 ∨ x1) are identical, so we can simplify the formula.  Also, (x1 ∨ x3) and (¬x1 ∨ x3) are identical, and (¬x2 ∨ ¬x1) and (¬x1 ∨ ¬x2) are identical.  Let's rewrite the formula as:\n(x1 ∨ ¬x3) ∧ (x2 ∨ x3) ∧ (x1 ∨ ¬x2) ∧ (x1 ∨ x3) ∧ (x3 ∨ x1) ∧ (¬x2 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (¬x2 ∨ x1) ∧ (¬x1 ∨ x3)\n\nSince (x1 ∨ ¬x3) appears twice, and (x1 ∨ x3) appears twice, we can simplify and rewrite the formula as:\n(x1 ∨ ¬x3) ∧ (x2 ∨ x3) ∧ (x1 ∨ ¬x2) ∧ (x3 ∨ x1) ∧ (¬x2 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (¬x2 ∨ x1) ∧ (¬x1 ∨ x3)\n\nLet's try some assignments.\nIf x1 = True, then:\n- (True ∨ ¬x3) = True, so we need ¬x3 to be True, i.e., x3 = False.\n- (x2 ∨ False) = x2, so x2 can be True or False.\n- (True ∨ ¬x2) = True, so ¬x2 can be True or False.\n- (True ∨ False) = True, so x3 = False.\n- (¬x2 ∨ ¬True) = ¬x2, so ¬x2 must be True, i.e., x2 = False.\n- (¬True ∨ False) = False, which is a contradiction.\n\nLet x1 = False.\n- (False ∨ ¬x3) = ¬x3, so x3 = True.\n- (x2 ∨ True) = True, so x2 can be anything.\n- (False ∨ ¬x2) = ¬x2, so x2 = False.\n- (False ∨ True) = True, so x3 = True.\n- (¬False ∨ ¬False) = True, so x3 = True.\n- (¬False ∨ True) = True, so x3 = True.\n- (¬False ∨ False) = False, which is a contradiction.\n\nLet's try x1 = True, x2 = False, x3 = True.\n(True ∨ ¬True) = True\n(False ∨ True) = True\n(True ∨ False) = True\n(True ∨ True) = True\n(True ∨ ¬False) = True\n(True ∨ True) = True\n(True ∨ True) = True\n(¬False ∨ ¬True) = True\n(¬True ∨ True) = True\n(True ∨ True) = True\n(¬False ∨ True) = True\n(¬True ∨ True) = True\n\nAll clauses are satisfied.\n\nFinal Answer: The final answer is $\\boxed{x1=True, x2=False, x3=True}$",
#   'latency_seconds': 12.53553695800656,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '3': True, '2': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (¬x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 2.1705276669963496,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 2,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ ¬x2) ∧ (¬x2 ∨ ¬x1) ∧ (x3 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.755199833001825,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 3,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x1) ∧ (x1 ∨ x3) ∧ (x1 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.8626452919997973,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 4,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ ¬x1) ∧ (¬x2 ∨ x3) ∧ (x1 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.6127675000025192,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 5,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ ¬x2) ∧ (x2 ∨ ¬x1) ∧ (¬x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.611881667005946,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 6,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ ¬x3) ∧ (x2 ∨ ¬x3) ∧ (¬x1 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=True, x3=False',
#   'latency_seconds': 1.599812041997211,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': False, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 7,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ ¬x3) ∧ (x2 ∨ ¬x1) ∧ (¬x1 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.591227249999065,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 8,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x1 ∨ ¬x2) ∧ (¬x2 ∨ x3) ∧ (¬x2 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.7842772910080384,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 9,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ x3) ∧ (¬x2 ∨ x3) ∧ (¬x1 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.9035826670005918,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 10,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ ¬x3) ∧ (x3 ∨ ¬x1) ∧ (x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.6159940000070492,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ ¬x3) ∧ (x1 ∨ x2) ∧ (x2 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.484886792008183,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': True},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 2,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ x1) ∧ (¬x3 ∨ ¬x1) ∧ (x2 ∨ x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.7370475830102805,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 3,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ ¬x3) ∧ (¬x3 ∨ x1) ∧ (¬x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.8608917920064414,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 4,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ ¬x1) ∧ (¬x1 ∨ x2) ∧ (x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=True, x3=False',
#   'latency_seconds': 1.4514319580048323,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': False, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 5,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ ¬x1) ∧ (¬x1 ∨ ¬x2) ∧ (x2 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=False, x3=True',
#   'latency_seconds': 1.496735583001282,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': False, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 6,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ x3) ∧ (¬x2 ∨ ¬x3) ∧ (x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.05237966599816,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 7,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ x1) ∧ (¬x3 ∨ ¬x2) ∧ (x1 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.7019337920064572,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 8,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ ¬x2) ∧ (x1 ∨ x3) ∧ (¬x1 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.9328158749995055,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 9,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ x2) ∧ (x2 ∨ ¬x1) ∧ (¬x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.700947791992803,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 10,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ x2) ∧ (¬x2 ∨ ¬x3) ∧ (¬x2 ∨ x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.7096768750052433,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ x3) ∧ (¬x2 ∨ ¬x3) ∧ (x3 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.8453085829969496,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x1 ∨ x3) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.3082602499925997,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 2,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ ¬x3) ∧ (x1 ∨ x3) ∧ (¬x2 ∨ x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.6364648330054479,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 3,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ ¬x3) ∧ (x2 ∨ ¬x3) ∧ (¬x3 ∨ x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.7338409169897204,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 4,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x2) ∧ (x2 ∨ x3) ∧ (x2 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.5792207909980789,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 5,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (x2 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.750876165999216,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 6,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x1) ∧ (¬x1 ∨ x2) ∧ (¬x2 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 2.05636712499836,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 7,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (¬x3 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=True, x3=False',
#   'latency_seconds': 1.0957955420017242,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': False, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 8,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ x3) ∧ (¬x1 ∨ x3) ∧ (¬x2 ∨ x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=True, x3=True',
#   'latency_seconds': 1.6034739169990644,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': True, '3': True},
#    'extraction': {'1': False, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 9,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x1 ∨ x3) ∧ (x3 ∨ ¬x1) ∧ (¬x2 ∨ x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.5780229160009185,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 10,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ ¬x1) ∧ (¬x2 ∨ x1) ∧ (¬x2 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.6104163749987492,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ x3) ∧ (x1 ∨ ¬x3) ∧ (¬x1 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.5699689589964692,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': True, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 2,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ ¬x3) ∧ (¬x1 ∨ ¬x2) ∧ (¬x3 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.5468597500002943,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 3,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ x2) ∧ (¬x1 ∨ ¬x2) ∧ (¬x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=False, x3=True',
#   'latency_seconds': 1.221442667010706,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': False, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 4,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ x3) ∧ (¬x2 ∨ x3) ∧ (¬x2 ∨ x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 2.349709874994005,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 5,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ x3) ∧ (¬x2 ∨ x1) ∧ (x2 ∨ x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.4765732499945443,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': True},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 6,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ x2) ∧ (x2 ∨ ¬x1) ∧ (x1 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.9710232080105925,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 7,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ x3) ∧ (¬x2 ∨ ¬x3) ∧ (¬x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.6637435000011465,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 8,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x1 ∨ ¬x3) ∧ (¬x3 ∨ ¬x1) ∧ (¬x3 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=False, x3=False',
#   'latency_seconds': 1.9549145830096677,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': False, '2': False, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 9,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x1) ∧ (x3 ∨ x1) ∧ (x1 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.678898375001154,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': False, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 10,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x1 ∨ ¬x3) ∧ (x2 ∨ x1) ∧ (x1 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.5422128749924013,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ x2) ∧ (x3 ∨ x2) ∧ (¬x1 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=False, x3=True',
#   'latency_seconds': 1.0652784169942606,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': False, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 2,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ x3) ∧ (x3 ∨ ¬x2) ∧ (x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.2084025000076508,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 3,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x1) ∧ (¬x3 ∨ x2) ∧ (¬x2 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.3960550420015352,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 4,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ x1) ∧ (¬x2 ∨ x3) ∧ (x2 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.7857709579984657,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 5,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x1 ∨ ¬x3) ∧ (x2 ∨ x3) ∧ (¬x1 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=True, x3=False',
#   'latency_seconds': 1.1251103329996113,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': False, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 6,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ ¬x1) ∧ (¬x2 ∨ x3) ∧ (¬x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.1472562499984633,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 7,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x1 ∨ ¬x2) ∧ (x3 ∨ x1) ∧ (x3 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.7330007499986095,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 8,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x2) ∧ (x1 ∨ ¬x2) ∧ (¬x3 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.2636621249985183,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 9,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ ¬x3) ∧ (x2 ∨ x1) ∧ (¬x1 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.57049850000476,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 10,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ ¬x1) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.4943757919972995,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ x2) ∧ (¬x1 ∨ ¬x2) ∧ (x3 ∨ ¬x2) ∧ (x1 ∨ x2) ∧ (¬x2 ∨ x1) ∧ (¬x3 ∨ x1) ∧ (¬x2 ∨ x3) ∧ (¬x2 ∨ ¬x1) ∧ (x1 ∨ x3) ∧ (x1 ∨ x2) ∧ (¬x2 ∨ x3) ∧ (¬x2 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.4683592079964,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 2,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ ¬x3) ∧ (¬x2 ∨ ¬x3) ∧ (x1 ∨ ¬x3) ∧ (¬x1 ∨ ¬x2) ∧ (¬x2 ∨ x3) ∧ (¬x3 ∨ ¬x2) ∧ (x2 ∨ ¬x3) ∧ (¬x1 ∨ ¬x2) ∧ (x1 ∨ ¬x2) ∧ (x2 ∨ x1) ∧ (¬x3 ∨ x1) ∧ (¬x2 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
# ...
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.7036183750024065,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 4,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ ¬x1) ∧ (x1 ∨ x2) ∧ (¬x1 ∨ x3) ∧ (x3 ∨ x1) ∧ (x3 ∨ x2) ∧ (x3 ∨ x1) ∧ (x1 ∨ x2) ∧ (x3 ∨ x2) ∧ (x2 ∨ x3) ∧ (x1 ∨ x3) ∧ (x1 ∨ x2) ∧ (x3 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.2342357080051443,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': True},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 5,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ x2) ∧ (x1 ∨ x3) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x1) ∧ (x1 ∨ x3) ∧ (x1 ∨ x3) ∧ (x2 ∨ x1) ∧ (¬x3 ∨ ¬x2) ∧ (¬x3 ∨ ¬x2) ∧ (x1 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.6924044999905163,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 6,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ x2) ∧ (x3 ∨ ¬x1) ∧ (x1 ∨ x3) ∧ (x3 ∨ x1) ∧ (x2 ∨ x1) ∧ (¬x1 ∨ ¬x2) ∧ (x1 ∨ ¬x2) ∧ (¬x2 ∨ x1) ∧ (x1 ∨ x3) ∧ (x3 ∨ x1) ∧ (x1 ∨ ¬x2) ∧ (¬x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.9903586669970537,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 7,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ x1) ∧ (¬x3 ∨ x2) ∧ (x3 ∨ x2) ∧ (¬x3 ∨ ¬x2) ∧ (x3 ∨ x2) ∧ (x2 ∨ x1) ∧ (¬x3 ∨ ¬x2) ∧ (x2 ∨ ¬x1) ∧ (¬x3 ∨ ¬x2) ∧ (¬x3 ∨ x2) ∧ (x2 ∨ x3) ∧ (¬x1 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 2.006638999999268,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 8,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ x3) ∧ (¬x3 ∨ ¬x2) ∧ (¬x2 ∨ ¬x3) ∧ (¬x2 ∨ x1) ∧ (¬x1 ∨ x3) ∧ (¬x2 ∨ x1) ∧ (¬x1 ∨ x3) ∧ (¬x1 ∨ ¬x3) ∧ (¬x2 ∨ ¬x1) ∧ (¬x2 ∨ ¬x1) ∧ (x3 ∨ ¬x2) ∧ (x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.2186427919950802,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 9,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ x2) ∧ (¬x3 ∨ ¬x2) ∧ (¬x3 ∨ x1) ∧ (¬x2 ∨ ¬x1) ∧ (¬x1 ∨ x3) ∧ (¬x2 ∨ ¬x1) ∧ (¬x1 ∨ ¬x3) ∧ (¬x3 ∨ ¬x2) ∧ (x3 ∨ ¬x2) ∧ (¬x3 ∨ x2) ∧ (x3 ∨ ¬x1) ∧ (¬x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.9410393750004005,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 10,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x1 ∨ x3) ∧ (x2 ∨ ¬x1) ∧ (x3 ∨ x2) ∧ (¬x1 ∨ ¬x2) ∧ (¬x1 ∨ x2) ∧ (¬x1 ∨ x3) ∧ (¬x1 ∨ ¬x2) ∧ (¬x2 ∨ x1) ∧ (¬x3 ∨ ¬x2) ∧ (¬x2 ∨ ¬x1) ∧ (¬x3 ∨ ¬x1) ∧ (x1 ∨ x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.6285695420083357,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ ¬x2) ∧ (x3 ∨ x1) ∧ (¬x1 ∨ x3) ∧ (¬x1 ∨ x2) ∧ (¬x1 ∨ ¬x2) ∧ (x3 ∨ ¬x2) ∧ (¬x3 ∨ x2) ∧ (¬x1 ∨ ¬x3) ∧ (x2 ∨ x3) ∧ (x3 ∨ x2) ∧ (¬x1 ∨ ¬x3) ∧ (¬x1 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.6415232909930637,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': True},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 2,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ x2) ∧ (x1 ∨ x2) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ ¬x3) ∧ (x2 ∨ ¬x1) ∧ (x3 ∨ x2) ∧ (¬x1 ∨ x2) ∧ (x1 ∨ ¬x2) ∧ (¬x1 ∨ x2) ∧ (¬x2 ∨ x1) ∧ (¬x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': "Let's analyze the 2-SAT formula:\n(x1 ∨ x2) ∧ (x1 ∨ x2) ∧ (x1 ∨ ¬x3) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ ¬x3) ∧ (x2 ∨ ¬x1) ∧ (x3 ∨ x2) ∧ (¬x1 ∨ x2) ∧ (x1 ∨ ¬x2) ∧ (¬x1 ∨ x2) ∧ (¬x2 ∨ x1) ∧ (¬x3 ∨ ¬x2)\n\nSince (x1 ∨ x2) appears twice, it's redundant. We can simplify the formula to:\n(x1 ∨ ¬x3) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ ¬x3) ∧ (x2 ∨ ¬x1) ∧ (x3 ∨ x2) ∧ (¬x1 ∨ x2) ∧ (x1 ∨ ¬x2) ∧ (¬x1 ∨ x2) ∧ (¬x2 ∨ x1) ∧ (¬x3 ∨ ¬x2)\n\nNow, let's try to find a satisfying assignment. We can use a brute-force approach or a more systematic method like strongly connected components (SCC) analysis.\n\nLet's try x1 = True.\n*   (True ∨ x2) is always true.\n*   (¬x3 ∨ x2)\n*   (True ∨ ¬x3) is always true.\n*   (x2 ∨ ¬True) = (x2 ∨ False) = x2\n*   (x3 ∨ x2)\n*   (¬True ∨ x2) = (False ∨ x2) = x2\n*   (True ∨ ¬x2) is always true.\n*   (¬True ∨ x2) = (False ∨ x2) = x2\n*   (¬x2 ∨ True) is always true.\n*   (¬x3 ∨ ¬x2)\n\nIf x1 = True, then x2 must be True to satisfy (x2 ∨ ¬x1) and (¬x1 ∨ x2).\nLet's assume x1 = True, x2 = True.\n*   (True ∨ True) = True\n*   (¬x3 ∨ True) = True\n*   (True ∨ ¬x3) = True\n*   (True ∨ ¬x3) = True\n*   (x3 ∨ True) = True\n*   (False ∨ True) = True\n*   (True ∨ False) = True\n*   (False ∨ True) = True\n*   (True ∨ False) = True\n*   (¬True ∨ True) = True\n*   (¬x3 ∨ ¬True) = (¬x3 ∨ False) = ¬x3\nSo, we need ¬x3 to be True, which means x3 = False.\n\nLet's check the original formula with x1=True, x2=True, x3=False:\n(True ∨ True) ∧ (True ∨ True) ∧ (True ∨ True) ∧ (True ∨ True) ∧ (True ∨ True) ∧ (True ∨ False) ∧ (False ∨ True) ∧ (False ∨ True) ∧ (True ∨ False) ∧ (True ∨ False) ∧ (False ∨ True) ∧ (True ∨ False)\n= True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True ∧ True\n= True\n\nTherefore, a satisfying assignment is x1=True, x2=True, x3=False.\n\nFinal Answer: The final answer is $\\boxed{x1=True, x2=True, x3=False}$",
#   'latency_seconds': 11.210802458008402,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 3,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ ¬x3) ∧ (¬x3 ∨ x2) ∧ (x1 ∨ x2) ∧ (¬x3 ∨ ¬x1) ∧ (x2 ∨ ¬x3) ∧ (x2 ∨ x1) ∧ (¬x1 ∨ ¬x2) ∧ (x3 ∨ ¬x1) ∧ (¬x3 ∨ x2) ∧ (x2 ∨ x1) ∧ (¬x1 ∨ x3) ∧ (¬x1 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=True',
#   'latency_seconds': 1.484888167004101,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x2 ∨ x1) ∧ (x2 ∨ x1) ∧ (¬x3 ∨ x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.3874268329964252,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ x2) ∧ (x3 ∨ x2) ∧ (x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.7865187080024043,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 2,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x1) ∧ (¬x1 ∨ x2) ∧ (x1 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.9450486250134418,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 3,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ ¬x2) ∧ (¬x3 ∨ ¬x1) ∧ (¬x2 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.6418192090059165,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 4,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ x1) ∧ (x2 ∨ x1) ∧ (¬x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.780304874991998,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 5,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x3 ∨ x2) ∧ (x3 ∨ x2) ∧ (¬x1 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 2.2037750409945147,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 6,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ x3) ∧ (x2 ∨ x3) ∧ (x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.6244443750038045,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': False, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 7,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ ¬x3) ∧ (x1 ∨ x3) ∧ (x3 ∨ ¬x2)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 2.0620981250103796,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': True},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 8,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x1 ∨ ¬x2) ∧ (¬x1 ∨ x2) ∧ (¬x1 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=True, x3=False',
#   'latency_seconds': 1.5771062089916086,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': False, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 9,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(¬x2 ∨ ¬x1) ∧ (¬x2 ∨ ¬x1) ∧ (¬x2 ∨ ¬x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=False, x2=False',
#   'latency_seconds': 1.3041515419899952,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': False, '2': True, '3': False},
#    'extraction': {'1': False, '2': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 10,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x3 ∨ ¬x2) ∧ (x1 ∨ ¬x2) ∧ (x1 ∨ ¬x3)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=True, x3=False',
#   'latency_seconds': 1.926258958003018,
#   'attempts': 1,
#   'metrics': {'correct': False,
#    'expected': {'1': True, '2': False, '3': False},
#    'extraction': {'1': True, '2': True, '3': False}},
#   'error': None},
#  {'model': 'unsloth/gemma-3-4b-it',
#   'index': 1,
#   'question': 'Find a satisfying assignment for the following 2-SAT formula over variables x1..x3:\n(x1 ∨ ¬x3) ∧ (x3 ∨ x1) ∧ (¬x3 ∨ x1)\nProvide your answer as comma-separated assignments like `x1=True, x2=False, ...`, or respond `UNSAT` if it has no solution.',
#   'response': 'x1=True, x2=False, x3=True',
#   'latency_seconds': 1.6463712920085527,
#   'attempts': 1,
#   'metrics': {'correct': True,
#    'expected': {'1': True, '2': True, '3': False},
#    'extraction': {'1': True, '2': False, '3': True}},
#   'error': None}]

# %%
import bittensor as bt
sub = bt.subtensor()
sub.set_reveal_commitment( wallet = bt.wallet(name = 'affine', hotkey = 'M1'), netuid = 120, data="unsloth/gemma-3-4b-it", blocks_until_reveal=1)

# %%
import bittensor as bt
sub = bt.subtensor()
sub.set_reveal_commitment( wallet = bt.wallet(name = 'affine', hotkey = 'M1'), netuid = 120, data="unsloth/gemma-3-4b-it", blocks_until_reveal=1)

# %%
import bittensor as bt
sub = bt.subtensor()
sub.set_reveal_commitment( wallet = bt.wallet(name = 'affine', hotkey = 'M1'), netuid = 120, data="unsloth/gemma-3-4b-it", blocks_until_reveal=1)

# %%
import bittensor as bt
sub = bt.subtensor()
sub.set_reveal_commitment( wallet = bt.wallet(name = 'affine', hotkey = 'M1'), netuid = 120, data="unsloth/gemma-3-4b-it", blocks_until_reveal=1)

# %%
import bittensor as bt
sub = bt.subtensor()
sub.set_reveal_commitment( wallet = bt.wallet(name = 'affine', hotkey = 'M1'), netuid = 120, data="unsloth/gemma-3-4b-it", blocks_until_reveal=1)

# %%
import bittensor as bt
sub = bt.subtensor()
sub.set_reveal_commitment( wallet = bt.wallet(name = 'affine', hotkey = 'M1'), netuid = 120, data="unsloth/gemma-3-4b-it", blocks_until_reveal=1)

# %%
sub.set_reveal_commitment( wallet = bt.wallet(name = 'affine', hotkey = 'M1'), netuid = 120, data="unsloth/gemma-3-4b-it", blocks_until_reveal=1)
# Out:
# (True, 19148209)

# %%
import bittensor as bt
asub = bt.async_subtensor()
await asub.initialize()
meta = await asub.metagraph(120)
reveals = await asub.get_all_revealed_commitments(120)
for uid in meta.uids:
    hotkey = meta.hotkeys[uid]
    try:
        block = reveals[hotkey][0][0]
        model = reveals[hotkey][0][1]
        print (uid, model)
    except: 
        pass
# Out:
# 5 unsloth/gemma-3-4b-it

# %%
import bittensor as bt
asub = bt.async_subtensor()
await asub.initialize()
reveals = await asub.get_all_revealed_commitments(120)
# Out:
# INFO     Enabling default logging (Warning level)
# 2025-06-18 16:10:34.472 |       INFO       | Enabling default logging (Warning level)

# %%
reveals
# Out:
# {'5H4QM65MVo6WU6MWeyE3spjRonXxascyxGzsCktUWbP8D8Ei': ((5808159,
#    'Alphatao/Affine-3590802'),
#   (5808255, 'Alphatao/Affine-6043407'),
#   (5808343, 'Alphatao/Affine-2922728'),
#   (5808405, 'Alphatao/Affine-9459823'),
#   (5808427, 'Alphatao/Affine-9459823'),
#   (5808453, 'Alphatao/Affine-9459823')),
#  '5Hjnirznzz3rYKodKCR2F2qzXC8ZjwZbUrt8w7CdbcPgYXMV': ((5807815,
#    'unsloth/gemma-3-4b-it'),)}
